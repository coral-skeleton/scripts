# %%
import numpy as np 
import matplotlib as mpl 
import matplotlib.pyplot as plt 
import vapeplot
#vapeplot.set_palette('vaporwave')
import seaborn as sns
sns.set_palette("tab10")

# %%
lsize = 28 
mpl.rc('xtick',direction='in',top=True) 
mpl.rc('ytick',direction='in',right=True) 
mpl.rcParams['contour.negative_linestyle'] = 'solid' 
plt.rc('font',family='sans-serif',serif='Helvetica',size=18) 
params = {'text.usetex': False, 'mathtext.fontset': 'cm', 'mathtext.default': 'regular', 'errorbar.capsize': 0} 
plt.rcParams.update(params) 

gname = 'J1059-09' 
outfolderS1 = '/media/user/System/Masters/processing/output/J1059-09_S1_fixed/'
outfolderS2 = '/media/user/System/Masters/processing/output/J1059-09_S2_fixed/'
outfolderS3 = '/media/user/System/Masters/processing/output/J1059-09_S3_fixed/'
outfolderS4 = '/media/user/System/Masters/processing/output/J1059-09_S4_fixed/'
outfolderS5 = '/media/user/System/Masters/processing/output/J1059-09_S5_fixed/'
outfolderS6 = '/media/user/System/Masters/processing/output/J1059-09_S6_fixed/'
outfolderN1 = '/media/user/System/Masters/processing/output/J1059-09_N1_fixed/'
outfolderN2 = '/media/user/System/Masters/processing/output/J1059-09_N2_fixed/'
outfolderN3 = '/media/user/System/Masters/processing/output/J1059-09_N3_fixed/'
twostage = 1

# %%
rad_sdS1, surfdens, sd_err = np.genfromtxt(outfolderS1+'densprof.txt', usecols=(0,3,4),unpack=True) 
radS1,vrot,disp,incS1,paS1,z0S1,xposS1,yposS1,vsys,vrad = np.genfromtxt(outfolderS1+'rings_final1.txt',usecols=(1,2,3,4,5,7,9,10,11,12),unpack=True) 
vrotS1 = vrot/1000
vsysS1 = vsys/1000
vradS1 = vrad/1000
dispS1 = disp/1000
surfdensS1 = surfdens/1000
sd_errS1 = sd_err/1000
try: err1_lS1, err1_hS1 = np.zeros(shape=(10,len(radS1))), np.zeros(shape=(10,len(radS1)))
except: err1_lS1, err1_hS1 = np.zeros(shape=(10,1)), np.zeros(shape=(10,1))
color=color2='#B22222' 
max_vrotS1,max_vdispS1 = np.nanmax(vrotS1),np.nanmax(dispS1) 
max_radS1 = 1.1*np.nanmax(radS1) 

if twostage: 
	rad2S1, vrot2,disp2,inc2S1,pa2S1,z02S1,xpos2S1,ypos2S1,vsys2, vrad2 = np.genfromtxt(outfolderS1+'rings_final2.txt',usecols=(1,2,3,4,5,7,9,10,11,12),unpack=True)
	vrot2S1 = vrot2/1000
	vsys2S1 = vsys2/1000
	disp2S1 = disp2/1000
	vrad2S1 = vrad2/1000
	err2_lS1, err2_hS1 = np.zeros(shape=(10,len(rad2S1))), np.zeros(shape=(10,len(rad2S1)))
	color='#A0A0A0' 
	max_radS1 = 1.1*np.nanmax(rad2S1) 
	max_vrotS1,max_vdispS1 = np.maximum(max_vrotS1,np.nanmax(vrot2S1)),np.maximum(max_vdispS1,np.nanmax(disp2S1))

# %%
rad_sdS2, surfdens, sd_err = np.genfromtxt(outfolderS2+'densprof.txt', usecols=(0,3,4),unpack=True) 
radS2,vrot,disp,incS2,paS2,z0S2,xposS2,yposS2,vsys,vrad = np.genfromtxt(outfolderS2+'rings_final1.txt',usecols=(1,2,3,4,5,7,9,10,11,12),unpack=True) 
vrotS2 = vrot/1000
vsysS2 = vsys/1000
vradS2 = vrad/1000
dispS2 = disp/1000
surfdensS2 = surfdens/1000
sd_errS2 = sd_err/1000
try: err1_lS2, err1_hS2 = np.zeros(shape=(10,len(radS2))), np.zeros(shape=(10,len(radS2)))
except: err1_lS2, err1_hS2 = np.zeros(shape=(10,1)), np.zeros(shape=(10,1))
color=color2='#B22222' 
max_vrotS2,max_vdispS2 = np.nanmax(vrotS2),np.nanmax(dispS2) 
max_radS2 = 1.1*np.nanmax(radS2) 

if twostage: 
	rad2S2, vrot2,disp2,inc2S2,pa2S2,z02S2,xpos2S2,ypos2S2,vsys2, vrad2 = np.genfromtxt(outfolderS2+'rings_final2.txt',usecols=(1,2,3,4,5,7,9,10,11,12),unpack=True)
	vrot2S2 = vrot2/1000
	vsys2S2 = vsys2/1000
	disp2S2 = disp2/1000
	vrad2S2 = vrad2/1000
	err2_lS2, err2_hS2 = np.zeros(shape=(10,len(rad2S2))), np.zeros(shape=(10,len(rad2S2)))
	color='#A0A0A0' 
	max_radS2 = 1.1*np.nanmax(rad2S2) 
	max_vrotS2,max_vdispS2 = np.maximum(max_vrotS2,np.nanmax(vrot2S2)),np.maximum(max_vdispS2,np.nanmax(disp2S2))

# %%
rad_sdS3, surfdens, sd_err = np.genfromtxt(outfolderS3+'densprof.txt', usecols=(0,3,4),unpack=True) 
radS3,vrot,disp,incS3,paS3,z0S3,xposS3,yposS3,vsys,vrad = np.genfromtxt(outfolderS3+'rings_final1.txt',usecols=(1,2,3,4,5,7,9,10,11,12),unpack=True) 
vrotS3 = vrot/1000
vsysS3 = vsys/1000
vradS3 = vrad/1000
dispS3 = disp/1000
surfdensS3 = surfdens/1000
sd_errS3 = sd_err/1000
try: err1_lS3, err1_hS3 = np.zeros(shape=(10,len(radS3))), np.zeros(shape=(10,len(radS3)))
except: err1_lS3, err1_hS3 = np.zeros(shape=(10,1)), np.zeros(shape=(10,1))
color=color2='#B22222' 
max_vrotS3,max_vdispS3 = np.nanmax(vrotS3),np.nanmax(dispS3) 
max_radS3 = 1.1*np.nanmax(radS3) 

if twostage: 
	rad2S3, vrot2,disp2,inc2S3,pa2S3,z02S3,xpos2S3,ypos2S3,vsys2, vrad2 = np.genfromtxt(outfolderS3+'rings_final2.txt',usecols=(1,2,3,4,5,7,9,10,11,12),unpack=True)
	vrot2S3 = vrot2/1000
	vsys2S3 = vsys2/1000
	disp2S3 = disp2/1000
	vrad2S3 = vrad2/1000
	err2_lS3, err2_hS3 = np.zeros(shape=(10,len(rad2S3))), np.zeros(shape=(10,len(rad2S3)))
	color='#A0A0A0' 
	max_radS3 = 1.1*np.nanmax(rad2S3) 
	max_vrotS3,max_vdispS3 = np.maximum(max_vrotS3,np.nanmax(vrot2S3)),np.maximum(max_vdispS3,np.nanmax(disp2S3))

# %%
rad_sdS4, surfdens, sd_err = np.genfromtxt(outfolderS4+'densprof.txt', usecols=(0,3,4),unpack=True) 
radS4,vrot,disp,incS4,paS4,z0S4,xposS4,yposS4,vsys,vrad = np.genfromtxt(outfolderS4+'rings_final1.txt',usecols=(1,2,3,4,5,7,9,10,11,12),unpack=True) 
vrotS4 = vrot/1000
vsysS4 = vsys/1000
vradS4 = vrad/1000
dispS4 = disp/1000
surfdensS4 = surfdens/1000
sd_errS4 = sd_err/1000
try: err1_lS4, err1_hS4 = np.zeros(shape=(10,len(radS4))), np.zeros(shape=(10,len(radS4)))
except: err1_lS4, err1_hS4 = np.zeros(shape=(10,1)), np.zeros(shape=(10,1))
color=color2='#B22222' 
max_vrotS4,max_vdispS4 = np.nanmax(vrotS4),np.nanmax(dispS4) 
max_radS4 = 1.1*np.nanmax(radS4) 

if twostage: 
	rad2S4, vrot2,disp2,inc2S4,pa2S4,z02S4,xpos2S4,ypos2S4,vsys2, vrad2 = np.genfromtxt(outfolderS4+'rings_final2.txt',usecols=(1,2,3,4,5,7,9,10,11,12),unpack=True)
	vrot2S4 = vrot2/1000
	vsys2S4 = vsys2/1000
	disp2S4 = disp2/1000
	vrad2S4 = vrad2/1000
	err2_lS4, err2_hS4 = np.zeros(shape=(10,len(rad2S4))), np.zeros(shape=(10,len(rad2S4)))
	color='#A0A0A0' 
	max_radS4 = 1.1*np.nanmax(rad2S4) 
	max_vrotS4,max_vdispS4 = np.maximum(max_vrotS4,np.nanmax(vrot2S4)),np.maximum(max_vdispS4,np.nanmax(disp2S4))

# %%
rad_sdS5, surfdens, sd_err = np.genfromtxt(outfolderS5+'densprof.txt', usecols=(0,3,4),unpack=True) 
radS5,vrot,disp,incS5,paS5,z0S5,xposS5,yposS5,vsys,vrad = np.genfromtxt(outfolderS5+'rings_final1.txt',usecols=(1,2,3,4,5,7,9,10,11,12),unpack=True) 
vrotS5 = vrot/1000
vsysS5 = vsys/1000
vradS5 = vrad/1000
dispS5 = disp/1000
surfdensS5 = surfdens/1000
sd_errS5 = sd_err/1000
try: err1_lS5, err1_hS5 = np.zeros(shape=(10,len(radS5))), np.zeros(shape=(10,len(radS5)))
except: err1_lS5, err1_hS5 = np.zeros(shape=(10,1)), np.zeros(shape=(10,1))
color=color2='#B22222' 
max_vrotS5,max_vdispS5 = np.nanmax(vrotS5),np.nanmax(dispS5) 
max_radS5 = 1.1*np.nanmax(radS5) 

if twostage: 
	rad2S5, vrot2,disp2,inc2S5,pa2S5,z02S5,xpos2S5,ypos2S5,vsys2, vrad2 = np.genfromtxt(outfolderS5+'rings_final2.txt',usecols=(1,2,3,4,5,7,9,10,11,12),unpack=True)
	vrot2S5 = vrot2/1000
	vsys2S5 = vsys2/1000
	disp2S5 = disp2/1000
	vrad2S5 = vrad2/1000
	err2_lS5, err2_hS5 = np.zeros(shape=(10,len(rad2S5))), np.zeros(shape=(10,len(rad2S5)))
	color='#A0A0A0' 
	max_radS5 = 1.1*np.nanmax(rad2S5) 
	max_vrotS5,max_vdispS5 = np.maximum(max_vrotS5,np.nanmax(vrot2S5)),np.maximum(max_vdispS5,np.nanmax(disp2S5))

# %%
rad_sdS6, surfdens, sd_err = np.genfromtxt(outfolderS6+'densprof.txt', usecols=(0,3,4),unpack=True) 
radS6,vrot,disp,incS6,paS6,z0S6,xposS6,yposS6,vsys,vrad = np.genfromtxt(outfolderS6+'rings_final1.txt',usecols=(1,2,3,4,5,7,9,10,11,12),unpack=True) 
vrotS6 = vrot/1000
vsysS6 = vsys/1000
vradS6 = vrad/1000
dispS6 = disp/1000
surfdensS6 = surfdens/1000
sd_errS6 = sd_err/1000
try: err1_lS6, err1_hS6 = np.zeros(shape=(10,len(radS6))), np.zeros(shape=(10,len(radS6)))
except: err1_lS6, err1_hS6 = np.zeros(shape=(10,1)), np.zeros(shape=(10,1))
color=color2='#B22222' 
max_vrotS6,max_vdispS6 = np.nanmax(vrotS6),np.nanmax(dispS6) 
max_radS6 = 1.1*np.nanmax(radS6) 

if twostage: 
	rad2S6, vrot2,disp2,inc2S6,pa2S6,z02S6,xpos2S6,ypos2S6,vsys2, vrad2 = np.genfromtxt(outfolderS6+'rings_final2.txt',usecols=(1,2,3,4,5,7,9,10,11,12),unpack=True)
	vrot2S6 = vrot2/1000
	vsys2S6 = vsys2/1000
	disp2S6 = disp2/1000
	vrad2S6 = vrad2/1000
	err2_lS6, err2_hS6 = np.zeros(shape=(10,len(rad2S6))), np.zeros(shape=(10,len(rad2S6)))
	color='#A0A0A0' 
	max_radS6 = 1.1*np.nanmax(rad2S6) 
	max_vrotS6,max_vdispS6 = np.maximum(max_vrotS6,np.nanmax(vrot2S6)),np.maximum(max_vdispS6,np.nanmax(disp2S6))

# %%
rad_sdN1, surfdens, sd_err = np.genfromtxt(outfolderN1+'densprof.txt', usecols=(0,3,4),unpack=True) 
radN1,vrot,disp,incN1,paN1,z0N1,xposN1,yposN1,vsys,vrad = np.genfromtxt(outfolderN1+'rings_final1.txt',usecols=(1,2,3,4,5,7,9,10,11,12),unpack=True) 
vrotN1 = vrot/1000
vsysN1 = vsys/1000
vradN1 = vrad/1000
dispN1 = disp/1000
surfdensN1 = surfdens/1000
sd_errN1 = sd_err/1000
try: err1_lN1, err1_hN1 = np.zeros(shape=(10,len(radN1))), np.zeros(shape=(10,len(radN1)))
except: err1_lN1, err1_hN1 = np.zeros(shape=(10,1)), np.zeros(shape=(10,1))
color=color2='#B22222' 
max_vrotN1,max_vdispN1 = np.nanmax(vrotN1),np.nanmax(dispN1) 
max_radN1 = 1.1*np.nanmax(radN1) 

if twostage: 
	rad2N1, vrot2,disp2,inc2N1,pa2N1,z02N1,xpos2N1,ypos2N1,vsys2, vrad2 = np.genfromtxt(outfolderN1+'rings_final2.txt',usecols=(1,2,3,4,5,7,9,10,11,12),unpack=True)
	vrot2N1 = vrot2/1000
	vsys2N1 = vsys2/1000
	disp2N1 = disp2/1000
	vrad2N1 = vrad2/1000
	err2_lN1, err2_hN1 = np.zeros(shape=(10,len(rad2N1))), np.zeros(shape=(10,len(rad2N1)))
	color='#A0A0A0' 
	max_radN1 = 1.1*np.nanmax(rad2N1) 
	max_vrotN1,max_vdispN1 = np.maximum(max_vrotN1,np.nanmax(vrot2N1)),np.maximum(max_vdispN1,np.nanmax(disp2N1))

# %%
rad_sdN2, surfdens, sd_err = np.genfromtxt(outfolderN2+'densprof.txt', usecols=(0,3,4),unpack=True) 
radN2,vrot,disp,incN2,paN2,z0N2,xposN2,yposN2,vsys,vrad = np.genfromtxt(outfolderN2+'rings_final1.txt',usecols=(1,2,3,4,5,7,9,10,11,12),unpack=True) 
vrotN2 = vrot/1000
vsysN2 = vsys/1000
vradN2 = vrad/1000
dispN2 = disp/1000
surfdensN2 = surfdens/1000
sd_errN2 = sd_err/1000
try: err1_lN2, err1_hN2 = np.zeros(shape=(10,len(radN2))), np.zeros(shape=(10,len(radN2)))
except: err1_lN2, err1_hN2 = np.zeros(shape=(10,1)), np.zeros(shape=(10,1))
color=color2='#B22222' 
max_vrotN2,max_vdispN2 = np.nanmax(vrotN2),np.nanmax(dispN2) 
max_radN2 = 1.1*np.nanmax(radN2) 

if twostage: 
	rad2N2, vrot2,disp2,inc2N2,pa2N2,z02N2,xpos2N2,ypos2N2,vsys2, vrad2 = np.genfromtxt(outfolderN2+'rings_final2.txt',usecols=(1,2,3,4,5,7,9,10,11,12),unpack=True)
	vrot2N2 = vrot2/1000
	vsys2N2 = vsys2/1000
	disp2N2 = disp2/1000
	vrad2N2 = vrad2/1000
	err2_lN2, err2_hN2 = np.zeros(shape=(10,len(rad2N2))), np.zeros(shape=(10,len(rad2N2)))
	color='#A0A0A0' 
	max_radN2 = 1.1*np.nanmax(rad2N2) 
	max_vrotN2,max_vdispN2 = np.maximum(max_vrotN2,np.nanmax(vrot2N2)),np.maximum(max_vdispN2,np.nanmax(disp2N2))

# %%
rad_sdN3, surfdens, sd_err = np.genfromtxt(outfolderN3+'densprof.txt', usecols=(0,3,4),unpack=True) 
radN3,vrot,disp,incN3,paN3,z0N3,xposN3,yposN3,vsys,vrad = np.genfromtxt(outfolderN3+'rings_final1.txt',usecols=(1,2,3,4,5,7,9,10,11,12),unpack=True) 
vrotN3 = vrot/1000
vsysN3 = vsys/1000
vradN3 = vrad/1000
dispN3 = disp/1000
surfdensN3 = surfdens/1000
sd_errN3 = sd_err/1000
try: err1_lN3, err1_hN3 = np.zeros(shape=(10,len(radN3))), np.zeros(shape=(10,len(radN3)))
except: err1_lN3, err1_hN3 = np.zeros(shape=(10,1)), np.zeros(shape=(10,1))
color=color2='#B22222' 
max_vrotN3,max_vdispN3 = np.nanmax(vrotN3),np.nanmax(dispN3) 
max_radN3 = 1.1*np.nanmax(radN3) 

if twostage: 
	rad2N3, vrot2,disp2,inc2N3,pa2N3,z02N3,xpos2N3,ypos2N3,vsys2, vrad2 = np.genfromtxt(outfolderN3+'rings_final2.txt',usecols=(1,2,3,4,5,7,9,10,11,12),unpack=True)
	vrot2N3 = vrot2/1000
	vsys2N3 = vsys2/1000
	disp2N3 = disp2/1000
	vrad2N3 = vrad2/1000
	err2_lN3, err2_hN3 = np.zeros(shape=(10,len(rad2N3))), np.zeros(shape=(10,len(rad2N3)))
	color='#A0A0A0' 
	max_radN3 = 1.1*np.nanmax(rad2N3) 
	max_vrotN3,max_vdispN3 = np.maximum(max_vrotN3,np.nanmax(vrot2N3)),np.maximum(max_vdispN3,np.nanmax(disp2N3))

# %%
fig=plt.figure(figsize=(20,20)) 
nrows, ncols = 2,3 
xlen, ylen = 0.27, 0.13 
x_sep, y_sep = 0.09,0.015 
bottom_corner = [0.0,0.7] 

for i in range (nrows): 
    bottom_corner[0], yl = 0.1, ylen 
    if i==0: yl *= 1.8 
    for j in range (ncols): 
        fig.add_axes([bottom_corner[0],bottom_corner[1],xlen,yl]) 
        #fig.axes[-1].set_xlim(0,max_rad) 
        if i==nrows-1: fig.axes[-1].tick_params(labelbottom=True) 
        else: fig.axes[-1].tick_params(labelbottom=False) 
        bottom_corner[0]+=xlen+x_sep 
    bottom_corner[1]-=(ylen+y_sep) 

ax = fig.axes 

# Plotting rotation velocity 
#ax[0].set_ylim(0,1.2*max_vrot) 
ax[0].set_ylabel('V$_\mathrm{rot}$ (km/s)', fontsize=lsize) 
ax[0].errorbar(rad2S1,vrot2S1, yerr=[-err2_lS1[0],err2_hS1[0]],fmt='o', markersize=10) 
ax[0].errorbar(rad2S2,vrot2S2, yerr=[-err2_lS2[0],err2_hS2[0]],fmt='o', markersize=10)
ax[0].errorbar(rad2S3,vrot2S3, yerr=[-err2_lS3[0],err2_hS3[0]],fmt='o', markersize=10)
ax[0].errorbar(rad2S4,vrot2S4, yerr=[-err2_lS4[0],err2_hS4[0]],fmt='o', markersize=10)
ax[0].errorbar(rad2S5,vrot2S5, yerr=[-err2_lS5[0],err2_hS5[0]],fmt='o', markersize=10)
ax[0].errorbar(rad2S6,vrot2S6, yerr=[-err2_lS6[0],err2_hS6[0]],fmt='o', markersize=10)
ax[0].errorbar(rad2N1,vrot2N1, yerr=[-err2_lN1[0],err2_hN1[0]],fmt='o', markersize=10)
ax[0].errorbar(rad2N2,vrot2N2, yerr=[-err2_lN2[0],err2_hN2[0]],fmt='o', markersize=10)
ax[0].errorbar(rad2N3,vrot2N3, yerr=[-err2_lN3[0],err2_hN3[0]],fmt='o', markersize=10)

# Plotting velocity dispersion 
#ax[1].set_ylim(0,1.2*max_vdisp) 
ax[1].set_ylabel('$\sigma_\mathrm{gas}$  (km/s)', fontsize=lsize) 
ax[1].errorbar(rad2S1,disp2S1, yerr=[-err2_lS1[1],err2_hS1[1]],fmt='o', markersize=10)
ax[1].errorbar(rad2S2,disp2S2, yerr=[-err2_lS2[1],err2_hS2[1]],fmt='o', markersize=10)
ax[1].errorbar(rad2S3,disp2S3, yerr=[-err2_lS3[1],err2_hS3[1]],fmt='o', markersize=10)
ax[1].errorbar(rad2S4,disp2S4, yerr=[-err2_lS4[1],err2_hS4[1]],fmt='o', markersize=10)
ax[1].errorbar(rad2S5,disp2S5, yerr=[-err2_lS5[1],err2_hS5[1]],fmt='o', markersize=10)
ax[1].errorbar(rad2S6,disp2S6, yerr=[-err2_lS6[1],err2_hS6[1]],fmt='o', markersize=10)
ax[1].errorbar(rad2N1,disp2N1, yerr=[-err2_lN1[1],err2_hN1[1]],fmt='o', markersize=10)
ax[1].errorbar(rad2N2,disp2N2, yerr=[-err2_lN2[1],err2_hN2[1]],fmt='o', markersize=10)
ax[1].errorbar(rad2N3,disp2N3, yerr=[-err2_lN3[1],err2_hN3[1]],fmt='o', markersize=10)

# Plotting surface density 
#ax[2].set_xlim(0,max_rad) 
ax[2].set_ylabel('$\Sigma$ (JY * KM/S)', fontsize=lsize) 
ax[2].errorbar(rad_sdS1,surfdensS1, yerr=sd_errS1,fmt='o', markersize=10, label = 'S1') 
ax[2].errorbar(rad_sdS2,surfdensS2, yerr=sd_errS2,fmt='o', markersize=10, label = 'S2')
ax[2].errorbar(rad_sdS3,surfdensS3, yerr=sd_errS3,fmt='o', markersize=10, label = 'S3')
ax[2].errorbar(rad_sdS4,surfdensS4, yerr=sd_errS4,fmt='o', markersize=10, label = 'S4')
ax[2].errorbar(rad_sdS5,surfdensS5, yerr=sd_errS5,fmt='o', markersize=10, label = 'S5')
ax[2].errorbar(rad_sdS6,surfdensS6, yerr=sd_errS6,fmt='o', markersize=10, label = 'S6')
ax[2].errorbar(rad_sdN1,surfdensN1, yerr=sd_errN1,fmt='o', markersize=10, label = 'Mkt11')
ax[2].errorbar(rad_sdN2,surfdensN2, yerr=sd_errN2,fmt='o', markersize=10, label = 'Mkt12')
ax[2].errorbar(rad_sdN3,surfdensN3, yerr=sd_errN3,fmt='o', markersize=10, label = 'Mkt13')


# Plotting inclination angle 
ax[3].set_ylabel('i (deg)', fontsize=lsize) 
ax[3].set_xlabel('Radius (arcsec)', fontsize=lsize) 
ax[3].errorbar(rad2S1,inc2S1,yerr=[-err2_lS1[4],err2_hS1[4]], fmt='o-', markersize=10)
ax[3].errorbar(rad2S2,inc2S2, yerr=[-err2_lS2[4],err2_hS2[4]],fmt='o-', markersize=10)
ax[3].errorbar(rad2S3,inc2S3, yerr=[-err2_lS3[4],err2_hS3[4]],fmt='o-', markersize=10)
ax[3].errorbar(rad2S4,inc2S4, yerr=[-err2_lS4[4],err2_hS4[4]],fmt='o-', markersize=10)
ax[3].errorbar(rad2S5,inc2S5, yerr=[-err2_lS5[4],err2_hS5[4]],fmt='o-', markersize=10)
ax[3].errorbar(rad2S6,inc2S6, yerr=[-err2_lS6[4],err2_hS6[4]],fmt='o-', markersize=10)
ax[3].errorbar(rad2N1,inc2N1, yerr=[-err2_lN1[4],err2_hN1[4]],fmt='o-', markersize=10)
ax[3].errorbar(rad2N2,inc2N2, yerr=[-err2_lN2[4],err2_hN2[4]],fmt='o-', markersize=10)
ax[3].errorbar(rad2N3,inc2N3, yerr=[-err2_lN3[4],err2_hN3[4]],fmt='o-', markersize=10)





# Plotting position angle 
ax[4].set_ylabel('$\phi$ (deg)', fontsize=lsize) 
ax[4].set_xlabel('Radius (arcsec)', fontsize=lsize) 
ax[4].errorbar(rad2S1,pa2S1, yerr=[-err2_lS1[5],err2_hS1[5]],fmt='o-', markersize=10)
ax[4].errorbar(rad2S2,pa2S2, yerr=[-err2_lS2[5],err2_hS2[5]],fmt='o-', markersize=10)
ax[4].errorbar(rad2S3,pa2S3, yerr=[-err2_lS3[5],err2_hS3[5]],fmt='o-', markersize=10)
ax[4].errorbar(rad2S4,pa2S4, yerr=[-err2_lS4[5],err2_hS4[5]],fmt='o-', markersize=10)
ax[4].errorbar(rad2S5,pa2S5, yerr=[-err2_lS5[5],err2_hS5[5]],fmt='o-', markersize=10)
ax[4].errorbar(rad2S6,pa2S6, yerr=[-err2_lS6[5],err2_hS6[5]],fmt='o-', markersize=10)
ax[4].errorbar(rad2N1,pa2N1, yerr=[-err2_lN1[5],err2_hN1[5]],fmt='o-', markersize=10)
ax[4].errorbar(rad2N2,pa2N2, yerr=[-err2_lN2[5],err2_hN2[5]],fmt='o-', markersize=10)
ax[4].errorbar(rad2N3,pa2N3, yerr=[-err2_lN3[5],err2_hN3[5]],fmt='o-', markersize=10)



# Plotting systemic velocity 
ax[5].set_ylabel('v$_\mathrm{sys}$ (km/s)', fontsize=lsize) 
ax[5].set_xlabel('Radius (arcsec)', fontsize=lsize)  
ax[5].errorbar(rad2S1,vsys2S1, yerr=[-err2_lS1[8],err2_hS1[8]],fmt='o', markersize=10, label = 'S1')
ax[5].errorbar(rad2S2,vsys2S2, yerr=[-err2_lS2[8],err2_hS2[8]],fmt='o', markersize=10, label = 'S2')
ax[5].errorbar(rad2S3,vsys2S3, yerr=[-err2_lS3[8],err2_hS3[8]],fmt='o', markersize=10, label = 'S3')
ax[5].errorbar(rad2S4,vsys2S4, yerr=[-err2_lS4[8],err2_hS4[8]],fmt='o', markersize=10, label = 'S4')
ax[5].errorbar(rad2S5,vsys2S5, yerr=[-err2_lS5[8],err2_hS5[8]],fmt='o', markersize=10, label = 'S5')
ax[5].errorbar(rad2S6,vsys2S6, yerr=[-err2_lS6[8],err2_hS6[8]],fmt='o', markersize=10, label = 'S6')
ax[5].errorbar(rad2N1,vsys2N1, yerr=[-err2_lN1[8],err2_hN1[8]],fmt='o', markersize=10, label = 'Mkt11')
ax[5].errorbar(rad2N2,vsys2N2, yerr=[-err2_lN2[8],err2_hN2[8]],fmt='o', markersize=10, label = 'Mkt12')
ax[5].errorbar(rad2N3,vsys2N3, yerr=[-err2_lN3[8],err2_hN3[8]],fmt='o', markersize=10, label = 'Mkt13')
    
handles, labels = ax[2].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right', ncol=9, fontsize = 24, markerscale = 1.5)
fig.savefig('parameters.pdf',bbox_inches='tight')
